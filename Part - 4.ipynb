# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# ## Creating Stings

# %%
s = 'pakistan'
#s = "pakistan"
# multiline strings
#s = '''pakistan'''
#s = """pakistan"""
#s = str('pakistan')
print(s)

# %%
'it's raining outside'
#"it's raining outside"

# %% [markdown]
# ## Accessing Substrings from a String

# %%
# Positive Indexing
s = 'Pakistan Zinda Abad'
print(s[0])

# %%
# Negative Indexing
s = 'Pakistan Zinda Abad'
print(s[-3])

# %%
# Slicing
s = 'Pakistan Zinda Abad'
print(s[0:4])
#print(s[6:0:-2])

# %%
print(s[::-1])

# %%
s = 'Pakistan Zinda Abad'
print(s[-1:-6:-1])

# %% [markdown]
# ## Editing and Deleting in Strings

# %%
s = 'hello world'
s[0] = 'H'

# Python strings are immutable

# %%
s = 'hello world'
del s
print(s)

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
print('Lahore' + ' ' + 'Karachi')

# %%
print('Lahore'*5)

# %%
print("*"*50)

# %%
'Lahore' != 'Lahore'

# %%
'Lahore' > 'Rawalpindi'
# lexiographically

# %%
'lahore' > 'Lahore'

# %%
'Pakistan' and 'India'

# %%
'Pakistan' or 'India'

# %%
'' and 'Pakistan'

# %%
'' or 'Pakistan'

# %%
'hello' or 'world'

# %%
'hello' and 'world'

# %%
not 'hello'

# %%
for i in 'Pakistan':
  print(i)

# %%
for i in 'Pakistan':
  print('Lahore')

# %%
'D' in 'Lahore'

# %% [markdown]
# ## Common Functions
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world')

# %%
sorted('hello world',reverse=True)

# %% [markdown]
# ## Capitalize/Title/Upper/Lower/Swapcase

# %%
s = 'hello world'
print(s.capitalize())
print(s)

# %%
s.title()

# %%
s.upper()

# %%
'Hello Wolrd'.lower()

# %%
'HeLlO WorLD'.swapcase()

# %% [markdown]
# ## Count/Find/Index

# %%
'my name is Noshad'.count('i')

# %%
'my name is Noshad'.find('x')
# Out:
# -1

# %%
'my name is Noshad'.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-12e2ad5b75e9> in <module>
# ----> 1 'my name is nitish'.index('x')
#
# ValueError: substring not found

# %% [markdown]
# ## endswith/startswith

# %%
'my name is noshad'.endswith('ad')

# %%
'my name is noshad'.startswith('name')

# %% [markdown]
# ## format

# %%
name = 'noshad'
gender = 'male'
'AOA! my name is {} and I am a {}'.format(gender,name)
#'AOA! my name is {0} and I am a {1}'.format(gender,name)

# %% [markdown]
# ## isalnum/ isalpha/ isdigit/ isidentifier

# %%
'noshad1234%'.isalnum()

# %%
'noshad'.isalpha()

# %%
'noshad'.isdigit()

# %%
'first-name'.isidentifier()

# %% [markdown]
# ## Split/Join

# %%
# Splitting a string by a space
'AOA! my name is noshad'.split()

# %%
# Splitting a string by a character
'AOA! my name is Kamran'.split('n')

# %%
" ".join(['AOA!', 'my', 'name', 'is', 'noshad'])

# %% [markdown]
# ## Replace

# %%
'AOA! my name is noshad'.replace('my name is noshad','I am a member of "UMT"')

# %% [markdown]
# ## Strip

# %%
# Remove extra spaces frm end
'The Knowledge City                           '.strip()
# Out:
# 'The Knowledge City'

# %% [markdown]
# ## Example Programs

# %%
# Find the length of a given string without using the len() function

s = input('enter the string ')

counter = 0

for i in s:
  counter += 1

print('length of string is',counter)
# Out:
# enter the string The Knowledge City
# length of string is 18

# %%
# Extract username from a given email.
# Eg if the email is Aqsa@umt.edu.pk
# then the username should be Miss Aqsa

s = input('enter the email ')

pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email aqSA@gmail.com
# aqSA

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email ')
term = input('what would like to search for')

counter = 0
for i in s:
  if i == term:
    counter += 1

print('frequency',counter)
# Out:
# enter the email aqsa@gmail,com
# what would like to search fora
# frequency 3

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string  ')
term = input('what would like to remove ')

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)
# Out:
# enter the string  gjjkklk;
# what would like to remove l
# gjjkkk;

# %%
# Write a program that can check whether a given string is palindrome or not.
# palindrome is a string that after reversing the orde it remain the same string
# CIVIC
# malayalam

s = input('enter the string ')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome ')
    break

if flag:
  print('Palindrome')
# Out:
# enter the string CIVIC
# Palindrome

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string ')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
# Out:
# enter the stringpalindrome
# ['palindrome']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string   ')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# enter the stringnoshad
# Noshad

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# enter the number345
# 345
# <class 'str'>

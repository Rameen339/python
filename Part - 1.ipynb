# %% [markdown]
# # 1. Python Output

# %% [markdown]
# # Python is a case sensitive language

# %%
#print and Print are different
print('Pakistan Zinda Abad')
print('Pakistan zinda abad')
# Out:
# Pakistan Zinda Abad
# Pakistan zinda abad

# %%
print('We are proud Asian')
# Out:
# We are proud Asian

# %%
print("Quid e Azam is a great man")
# Out:
# Quid e Azam is a great man

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %% [markdown]
# ## Print is most powerful function

# %%
print()

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='*')
# Out:
# Hello*1*4.5*True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e308)
# Out:
# 8
# 1e+308

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
type({1,2,3,4,5})
# Out:
# set

# %%
# Dictionary
print({'Name':'Jamil','Gender':'Male','Age':86,'Weight':70})
# Out:
# {'Name': 'Jamil', 'Gender': 'Male', 'Age': 86, 'Weight': 70}

# %%
# type
type({'Name':'Jamil','Gender':'Male','Age':86,'Weight':70})
# Out:
# dict

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# C/C++
name = 'Jamil'
print(name)

a = 7
b = 11

print(a + b)
# Out:
# Jamil
# 18

# %%
# Dynamic Typing (Interview Question)
a = 5
# Static Typing
int a = 5

# %%
# Dynamic Binding (Interview Question)
a = 5
print(a)
a = 'Jamil'
print(a)

# Static Binding
#int a = 5
# Out:
# 5
# Jamil

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = 'Jamil'
print(name1)
# You can use special chars -> _
_ = 'Jamil'
print(_)
# identiers can not be keyword
# Out:
# Jamil
# Jamil

# %% [markdown]
# # 5. Type Conversion

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

#print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
# Explicit
# str -> int
#int('4')
#type(int('4'))
#type(int(4.7))
#int(4+5j)

# int to str
#str(5)

# float
#float(4)

# %% [markdown]
# # 6. User Input

# %%
# Static Vs Dynamic
input()
#input('Enter Email')
# Out:
# ''

# %%
# take input from users and store them in a variable
Firstnum = input('enter first number=')
Secondnum = input('enter second number=')
#Firstnum = int(input('enter first number'))
#Secondnum = int(input('enter second number'))
#print(type(fnum),type(snum))
# add the 2 variables
result = int(Firstnum) + int(Secondnum)
# print the result
print(result)
print(type(Firstnum))
# Out:
# enter first number=2
# enter second number=4
# 6
# <class 'str'>

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)

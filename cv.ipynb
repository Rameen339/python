# %% [markdown]
# <a href="https://colab.research.google.com/github/Rameen339/python/blob/main/cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
